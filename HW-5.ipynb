# %% [markdown]
# # Задание 1
# Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# {‘1840e0b9d4’: ‘Продукты’, …}

# %%
import json

purchases = {}

with open('purchase_log.txt', 'r', encoding='utf-8') as file:
    file.seek(0)
    for i in file:
        line = file.readline().strip() #читаем построчно. strip() удаляет перенос строки \n
        y_ = json.loads(line) #строку привели к словарю
        purchases[y_['user_id']] = y_['category']

print(purchases)
# Out:
# {'1840e0b9d4': 'Продукты', 'afea8d72fc': 'Электроника', '9b2ab046f3': 'Электроника', '44edeffc91': 'Продукты', '1de31be403': 'Бытовая техника', '79843a685a': 'Продукты', 'e8447c40e2': 'Досуг', 'fa0079a5a8': 'Досуг', '3f8e1ccd3f': 'Электроника', '65f44a2eb7': 'Досуг', '3ecff691fd': 'Электроника', '9250593d55': 'Электроника', '22fa3ea76f': 'Электроника', 'f983a69d67': 'Товары для животных', 'c6de96a5e2': 'Товары для животных', '680aa815f9': 'Продукты', '905e60cb52': 'Бытовая техника', '06d450cc57': 'Электроника', '6f159c4c2e': 'Товары для животных', '1908683775': 'Электроника', '72e0a3f1d0': 'Бытовая техника', 'bc1a0a7e26': 'Досуг', '74c9201f84': 'Электроника', 'fe4615dd15': 'Досуг', 'f0a93d52d2': 'Электроника', 'dbe70d84e4': 'Строительство и ремонт', 'f93283c9ee': 'Бытовая техника', '111c52d9bc': 'Продукты', '87f37b380c': 'Продукты', '7d6c62f0a2': 'Бытовая техника', 'ee9eb52181': 'Товары для животных', '03b91dba06': 'Электроника', '9ab8f3bbb8': 'Бытовая техника', '2ffd6c724d': 'Продукты', '421149bb9a': 'Строительство и ремонт', '9ca11a651f': 'Электроника', '3691ad282b': 'Электроника', '6f198ac1c9': 'Бытовая техника', 'b461051101': 'Досуг', '316ab03143': 'Товары для животных', '19d1e4e036': 'Товары для животных', 'ddd50eaa45': 'Электроника', 'da79d9ff30': 'Товары для животных', 'e3654c7f1a': 'Досуг', '12de58d8e6': 'Продукты', 'dfe6f4ebb4': 'Бытовая техника', 'd47dd8b814': 'Электроника', 'a86e69db63': 'Продукты', '152ea9bb42': 'Бытовая техника', '9f5bf9b73f': 'Строительство и ремонт', '0cf6ee6c84': 'Бытовая техника', '716a1b4e10': 'Продукты', 'c0cd6e93e6': 'Электроника', 'f537f6c8ea': 'Бытовая техника', '29586e4061': 'Продукты', 'da237781d5': 'Продукты', '62f37b821c': 'Досуг', '7fa3bf64b4': 'Досуг', '6812661e1c': 'Электроника', '88afad2ad9': 'Продукты', 'bed9ab14bd': 'Товары для животных', '80023b95ac': 'Электроника', 'f34a165ad2': 'Электроника', '5655da0e0b': 'Электроника', 'b15321ea7c': 'Продукты', 'a2468d6c33': 'Электроника', 'a7bfa5d0cc': 'Досуг', '48b9ea8b65': 'Электроника', '69775511be': 'Досуг', 'ca899d23dd': 'Бытовая техника', '0da9ca70fe': 'Продукты', '51f6ce88cc': 'Бытовая техника', '69475b45df': 'Бытовая техника', '28ce699720': 'Бытовая техника', 'c577b4b31e': 'Продукты', '1405e18ffb': 'Досуг', '4cd8bde9ac': 'Продукты', '853f7ea287': 'Продукты', '8c45fdbf5a': 'Электроника', '55effa36e0': 'Продукты', '33a4dbd193': 'Электроника', 'e371c40a07': 'Электроника', 'fceaddb1f5': 'Электроника', 'a7091d1405': 'Бытовая техника', 'a8c4da0681': 'Электроника', '9b63ed579f': 'Строительство и ремонт', '9cdc26ff6c': 'Электроника', 'bc40fc5c3b': 'Продукты', '800ad1974f': 'Электроника', 'fbcb38042a': 'Бытовая техника', '1909ff3b18': 'Продукты', '36d248e31c': 'Продукты', '44174c696c': 'Продукты', '2ffcf27605': 'Бытовая техника', '24c047fa51': 'Электроника', 'd9a640bee2': 'Электроника', 'bbec49524b': 'Электроника', '5392a9dd06': 'Строительство и ремонт', '8e7cb8744a': 'Продукты', 'c1a0da9976': 'Электроника', '49e9a83a56': 'Электроника', '9c4d9e37b8': 'Электроника', 'd61df629df': 'Продукты', '73d9a7f6d5': 'Продукты', 'eb7ff574cc': 'Электроника', '3def3c47e0': 'Электроника', '5a8c6a6214': 'Досуг', '301db812db': 'Электроника', 'ba38172577': 'Досуг', 'ac317ed5da': 'Электроника', '5e5398d531': 'Электроника', '81ebf6e699': 'Электроника', '3953e7d027': 'Электроника', 'b3347f9015': 'Электроника', '61f09c8e23': 'Электроника', 'ccdb17354a': 'Продукты', '0a22ae5507': 'Электроника', '7e33fda510': 'Электроника', 'bdec18f74e': 'Продукты', '9df56d0753': 'Продукты', '422ac66d5a': 'Электроника', 'd8557c45f3': 'Продукты', '987dc6321c': 'Электроника', 'deba35d5a8': 'Бытовая техника', '3f93050f90': 'Досуг', '73aa62d288': 'Электроника', 'c9ca4f00dd': 'Продукты', '991072196d': 'Бытовая техника', '642295148f': 'Электроника', 'f127ee3e08': 'Бытовая техника', '28ed9a2680': 'Товары для животных', 'ec0d778ca8': 'Электроника', '26daa6bcff': 'Товары для животных', 'a771274455': 'Строительство и ремонт', '0f359c5def': 'Электроника', 'b694d9fb7e': 'не определена', 'e50f7 ...

# %% [markdown]
# # Задание 2
# Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
# Учтите условия на данные:
# содержимое purchase_log.txt помещается в оперативную память компьютера
# содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %%
import json

with open ('visit_log.csv', 'r', encoding='utf-8') as vizit:
        with open('funnel.csv', 'w') as funnel:
            
             for y in vizit:
                line_1 = vizit.readline().strip() 
                list_id_category = line_1.split(',') #приводим строку к списку, чтоб удобнее работать
                user_id_v = list_id_category[0] #получаем user_id посетителя 
                #print('Покупатель', user_id_v)
                
                for k, v in purchases.items():
                    if k == user_id_v:
                        str_ = ''
                        str_ = k + ' ' + v + ' ' + list_id_category[1] #str_ - промежуточная переменная, которую будем выводить на экран. собираем строку: user_id, категория, канал привлечения
                    
                        funnel.write(f'{str_} \n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-170-7be6dde420a9> in <module>
#      10                 #print('Покупатель', user_id_v)
#      11
# ---> 12                 for k, v in purchases.items():
#      13                     if k == user_id_v:
#      14                         str_ = ''
#
# KeyboardInterrupt:
